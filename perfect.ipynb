# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from collections import deque, namedtuple
import random
from TicTacToe import TicTacToe

gamma = 0.95
learning_rate = 0.001
batch_size = 32
episodes = 5000
epsilon_start = 1.0
epsilon_end = 0.01
epsilon_decay = 0.995

Transition = namedtuple('Transition', ('state', 'action', 'reward', 'next_state', 'done'))
replay_buffer = deque(maxlen=2000)

model = Sequential([
    Dense(64, input_dim=9, activation='relu'),
    Dense(64, activation='relu'),
    Dense(9, activation='linear')
])
model.compile(loss='mse', optimizer=Adam(learning_rate=learning_rate))

def generate_random_state():
    env = TicTacToe(smartMovePlayer1=0.5)
    board = [0] * 9
    num_moves = random.randint(1, 9)
    moves_made = 0
    player_turn = 1

    while moves_made < num_moves:
        valid_actions = [i for i in range(9) if board[i] == 0]
        pos = random.choice(valid_actions)
        board[pos] = player_turn
        env.board = board
        if env.check_winner(player_turn):
            break
        moves_made += 1
        player_turn = 3 - player_turn

    env.board = board
    return env, player_turn

def epsilon_greedy_action(state, env, epsilon):
    valid_actions = env.empty_positions()
    if not valid_actions:
        return None
    if np.random.rand() <= epsilon:
        return random.choice(valid_actions)
    q_values = model.predict(state, verbose=0)
    q_values_valid = [q_values[0][i] for i in valid_actions]
    return valid_actions[np.argmax(q_values_valid)]

def train_on_replay():
    if len(replay_buffer) < batch_size:
        return
    transitions = random.sample(replay_buffer, batch_size)
    states, actions, rewards, next_states, dones = zip(*transitions)

    states = np.array(states, dtype=float).reshape(batch_size, -1)
    next_states = np.array(next_states, dtype=float).reshape(batch_size, -1)
    target_q_values = rewards + gamma * np.max(model.predict(next_states, verbose=0), axis=1) * (1 - np.array(dones))
    target_f = model.predict(states, verbose=0)
    for i, action in enumerate(actions):
        target_f[i][action] = target_q_values[i]
    model.fit(states, target_f, epochs=1, verbose=0)

valid_episodes = []
for _ in range(5000):
    env, player_turn = generate_random_state()
    valid_episodes.append((env, player_turn))

epsilon = epsilon_start
win, draw, loss = 0, 0, 0
for e, (env, current_player) in enumerate(valid_episodes):
    state = np.reshape(env.board, [1, 9])
    done = False

    while not done:
        if current_player == 2:
            action = epsilon_greedy_action(state, env, epsilon)
            if action is None:
                break
            env.make_move(action, 2)
            reward = env.get_reward()
            done = env.is_full() or env.current_winner is not None
            next_state = np.reshape(env.board, [1, 9])
            replay_buffer.append(Transition(state, action, reward, next_state, done))
            state = next_state
        else:
            if not env.is_full() and env.current_winner is None:
                env.player1_move()
            done = env.is_full() or env.current_winner is not None

        if done:
            if reward == 1:
                loss += 1
            elif reward == -1:
                win += 1
            else:
                draw += 1

        current_player = 3 - current_player
        train_on_replay()
        epsilon = max(epsilon * epsilon_decay, epsilon_end)

    print(f"Episode {e+1}/{episodes}, Win: {win}, Draw: {draw}, Loss: {loss}")

model.save('YourBITSid_MODEL2.h5')
# Out:
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 1
# Episode 1/5000, Win: 0, Draw: 0, Loss: 1
# Player 1 (Smart/Random) chooses position 5
# Episode 2/5000, Win: 0, Draw: 1, Loss: 1
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 7
# Episode
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Episode 4980/5000, Win: 0, Draw: 3787, Loss: 1120
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Episode 4981/5000, Win: 0, Draw: 3788, Loss: 1120
# Episode 4982/5000, Win: 0, Draw: 3788, Loss: 1121
# Player 1 (Smart/Random) chooses position 1
# Episode 4983/5000, Win: 0, Draw: 3789, Loss: 1121
# Player 1 (Smart/Random) chooses position 7
# Episode 4984/5000, Win: 0, Draw: 3790, Loss: 1121
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Episode 4985/5000, Win: 0, Draw: 3791, Loss: 1121
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 1
# Episode 4986/5000, Win: 0, Draw: 3792, Loss: 1121
# Player 1 (Smart/Random) chooses position 4
# Episode 4987/5000, Win: 0, Draw: 3793, Loss: 1121
# Player 1 (Smart/Random) chooses position 3
# Episode 4988/5000, Win: 0, Draw: 3794, Loss: 1121
# Episode 4989/5000, Win: 0, Draw: 3794, Loss: 1122
# Player 1 (Smart/Random) chooses position 9
# Episode 4990/5000, Win: 0, Draw: 3795, Loss: 1122
# Player 1 (Smart/Random) chooses position 5
# Episode 4991/5000, Win: 0, Draw: 3796, Loss: 1122
# Player 1 (Smart/Random) chooses position 3
# Episode 4992/5000, Win: 0, Draw: 3797, Loss: 1122
# Player 1 (Smart/Random) chooses position 3
# Episode 4993/5000, Win: 0, Draw: 3798, Loss: 1122
# Player 1 (Smart/Random) chooses position 2
# Episode 4994/5000, Win: 0, Draw: 3799, Loss: 1122
# Player 1 (Smart/Random) chooses position 3
# Episode 4995/5000, Win: 0, Draw: 3800, Loss: 1122
# Player 1 (Smart/Random) chooses position 1
# Episode 4996/5000, Win: 0, Draw: 3801, Loss: 1122
# Player 1 (Smart/Random) chooses position 5
# Episode 4997/5000, Win: 0, Draw: 3802, Loss: 1122
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 9
# Episode 4998/5000, Win: 0, Draw: 3803, Loss: 1122
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 7
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Episode 4999/5000, Win: 0, Draw: 3804, Loss: 1122
# Player 1 (Smart/Random) chooses position 6
# Episode 5000/5000, Win: 0, Draw: 3805, Loss: 1122

# %%
import sys
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import register_keras_serializable
from TicTacToe import TicTacToe

@register_keras_serializable()
def mse(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true - y_pred))

class PlayerSQN:
    def __init__(self, model_path='YourBITSid_MODEL2.h5'):
        """
        Initializes the PlayerSQN class and loads the pre-trained model.
        """
        try:
            custom_objects = {'mse': mse}
            self.model = load_model(model_path, custom_objects=custom_objects)
            print("Model loaded successfully!")
        except Exception as e:
            print(f"Error: Could not load model. {e}")
            sys.exit(1)
    
    def _preprocess_state(self, state):
        """
        Converts the state from [0,1,2] format to [-1,0,1] format for better learning.
        """
        processed_state = np.array(state).copy()
        processed_state[processed_state == 2] = -1
        return processed_state

    def move(self, state):
        """
        Selects the best move based on the current state.
        """
        processed_state = self._preprocess_state(state)
        valid_moves = [i for i, val in enumerate(state) if val == 0]
        
        q_values = self.model.predict(processed_state.reshape(1, -1), verbose=0)[0]
        # Mask invalid moves
        for i in range(len(q_values)):
            if i not in valid_moves:
                q_values[i] = float('-inf')
        return np.argmax(q_values)

def simulate_games(smartMovePlayer1, num_games=100):
    """
    Simulates multiple TicTacToe games and tracks the results.

    Parameters:
    smartMovePlayer1: Probability that Player 1 will make a smart move at each time step.
    num_games: Number of games to simulate.
    """
    playerSQN = PlayerSQN()
    wins, losses, draws = 0, 0, 0

    for _ in range(num_games):
        game = TicTacToe(smartMovePlayer1, playerSQN)
        game.play_game()
        
        reward = game.get_reward()
        if reward == 1:
            wins += 1
        elif reward == -1:
            losses += 1
        else:
            draws += 1

    print(f"Results after {num_games} games:")
    print(f"Wins: {wins}")
    print(f"Losses: {losses}")
    print(f"Draws: {draws}")

if __name__ == "__main__":
    try:
        smartMovePlayer1 = 0.5
        assert 0 <= smartMovePlayer1 <= 1
    except:
        print("Usage: python YourBITSid.py <smartMovePlayer1Probability>")
        print("Example: python 2021A7PS2627G.py 0.5")
        print("Error: Probability must lie between 0 and 1.")
        sys.exit(1)
    
    simulate_games(smartMovePlayer1)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   | X
# ---+---+---
#    |   | X
# ---+---+---
#    | O |
#
#
# Board:
#    |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
#
# Board:
#  X |   |
# ---+---+---
#  O |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  X |   |
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
#
# Board:
#  X |   | O
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  X | X | O
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | O
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  X | X | O
# ---+---+---
#  O | X | O
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 8
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | X |
#
#
# Board:
#    |   |
# ---+---+---
#  O |   |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | X |
#
#
# Board:
#    |   | O
# ---+---+---
#  O | X |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   | O
# ---+---+---
#  O | X |
# ---+---+---
#  X | X |
#
#
# Board:
#  O |   | O
# ---+---+---
#  O | X |
# ---+---+---
#  X | X |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  O | X | O
# ---+---+---
#  O | X |
# ---+---+---
#  X | X |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O | X
#
#
# Board:
#    |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
#
# Board:
#  O |   | X
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  O | X | X
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
#
# Board:
#  O | X | X
# ---+---+---
#  O | X | O
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  O | X | X
# ---+---+---
#  O | X | O
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   | X
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
#
# Board:
#    |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
#
# Board:
#  X |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  X |   | X
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
#
# Board:
#  X |   | X
# ---+---+---
#  O | X |
# ---+---+---
#    | O | O
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  X |   | X
# ---+---+---
#  O | X |
# ---+---+---
#  X | O | O
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X |   |
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#  X | O |
#
#
# Board:
#    |   | X
# ---+---+---
#  O |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O |
#
#
# Board:
#  O |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O |   | X
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 8
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | X |
#
#
# Board:
#    |   |
# ---+---+---
#  O |   |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#  O |   |
# ---+---+---
#    | X | X
#
#
# Board:
#    |   | O
# ---+---+---
#  O |   |
# ---+---+---
#    | X | X
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   | O
# ---+---+---
#  O |   |
# ---+---+---
#  X | X | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   | X
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
#
# Board:
#    |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O | X
#
#
# Board:
#  O | X | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#  O | X | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    | X | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
#
# Board:
#    | X | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X | X | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
#
# Board:
#  X |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#  X |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
#
# Board:
#    | X | O
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    | X | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O |
#
#
# Board:
#  O | X | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#  O | X | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O | X
#
#
# Board:
#  O | X | O
# ---+---+---
#  X |   | X
# ---+---+---
#  O | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O | X | O
# ---+---+---
#  X | X | X
# ---+---+---
#  O | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
#
# Board:
#  X |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#  X |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
#
# Board:
#  X |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | O
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  X | X | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | O
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   |
# ---+---+---
#  X |   | X
# ---+---+---
#    | O |
#
#
# Board:
#    |   | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   | O
# ---+---+---
#  X | X | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   | X
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O | X
#
#
# Board:
#    |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 8
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | X |
#
#
# Board:
#    |   |
# ---+---+---
#  O |   |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | X |
#
#
# Board:
#  O |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  O |   | X
# ---+---+---
#  O |   |
# ---+---+---
#  X | X |
#
#
# Board:
#  O |   | X
# ---+---+---
#  O |   |
# ---+---+---
#  X | X | O
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O |   | X
# ---+---+---
#  O | X |
# ---+---+---
#  X | X | O
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   | X
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
#
# Board:
#    |   | X
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   | X
# ---+---+---
#  O | X |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
#
# Board:
#    | X | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    | X | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
#
# Board:
#  O | X | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#  O | X | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    | X |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
#
# Board:
#    | X |
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X | X |
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
#
# Board:
#  X | X | O
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#  X | X | O
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X |   |
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#  X | O |
#
#
# Board:
#    |   | X
# ---+---+---
#  O |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   | X
# ---+---+---
#  O | X |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   |
# ---+---+---
#    | X | X
# ---+---+---
#    | O |
#
#
# Board:
#    |   |
# ---+---+---
#  O | X | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#  O | X | X
# ---+---+---
#    | O |
#
#
# Board:
#    | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#    | O | X
#
#
# Board:
#  O | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  O | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | X
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#  X | O |
#
#
# Board:
#    |   | O
# ---+---+---
#  X |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   | O
# ---+---+---
#  X |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 8
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | X |
#
#
# Board:
#    |   |
# ---+---+---
#  O |   |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | X |
#
#
# Board:
#    |   | O
# ---+---+---
#  O | X |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   | O
# ---+---+---
#  O | X |
# ---+---+---
#    | X | X
#
#
# Board:
#  O |   | O
# ---+---+---
#  O | X |
# ---+---+---
#    | X | X
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  O | X | O
# ---+---+---
#  O | X |
# ---+---+---
#    | X | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 8
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | X |
#
#
# Board:
#    |   |
# ---+---+---
#  O |   |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | X |
#
#
# Board:
#    |   | O
# ---+---+---
#  O | X |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X | O
# ---+---+---
#  O | X |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
#
# Board:
#    |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   |
# ---+---+---
#    |   | X
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   | X
# ---+---+---
#    | O |
#
#
# Board:
#    |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
#
# Board:
#  X |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  X | X | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
#
# Board:
#  X |   |
# ---+---+---
#  O |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#  X |   |
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
#
# Board:
#  X |   | O
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  X |   | O
# ---+---+---
#  O | X | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   | X
# ---+---+---
#    |   | X
# ---+---+---
#    | O |
#
#
# Board:
#    |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  X |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
#
# Board:
#  X |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  X | X |
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
#
# Board:
#  X | X | O
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#  X | X | O
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   | X
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O | X
#
#
# Board:
#    |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
#
# Board:
#  X |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#  X |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
#
# Board:
#  X |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | O
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  X |   | X
# ---+---+---
#  O | X | X
# ---+---+---
#    | O | O
#
#
# Board:
#  X | O | X
# ---+---+---
#  O | X | X
# ---+---+---
#    | O | O
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  X | O | X
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | O
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   |
# ---+---+---
#  X |   | X
# ---+---+---
#    | O |
#
#
# Board:
#    |   | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   | O
# ---+---+---
#  X | X | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#  X |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
#
# Board:
#  X |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  X | X | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   |
# ---+---+---
#    | X | X
# ---+---+---
#    | O |
#
#
# Board:
#    |   |
# ---+---+---
#  O | X | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O |
#
#
# Board:
#    |   | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | X
#
#
# Board:
#  O |   | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  O | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | X
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
#
# Board:
#    | X | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X | X | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   |
# ---+---+---
#  X | X |
# ---+---+---
#    | O |
#
#
# Board:
#    |   | O
# ---+---+---
#  X | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   | O
# ---+---+---
#  X | X | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   |
# ---+---+---
#  X |   | X
# ---+---+---
#    | O |
#
#
# Board:
#    |   | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O | X
#
#
# Board:
#  O |   | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O |   | O
# ---+---+---
#  X | X | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    | X |
# ---+---+---
#    |   | X
# ---+---+---
#    | O |
#
#
# Board:
#    | X |
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X | X |
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O |
#
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O | O
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  X | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | O
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#  X | O |
#
#
# Board:
#    |   |
# ---+---+---
#  O | X |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#  O | X |
# ---+---+---
#  X | O | X
#
#
# Board:
#    |   | O
# ---+---+---
#  O | X |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   | O
# ---+---+---
#  O | X |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   |
# ---+---+---
#    |   | X
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#    |   | X
# ---+---+---
#    | O | X
#
#
# Board:
#    |   |
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
#
# Board:
#  X |   | O
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#  O | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  X | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  O | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 8
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | X |
#
#
# Board:
#    |   |
# ---+---+---
#  O |   |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | X |
#
#
# Board:
#    |   | O
# ---+---+---
#  O | X |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X | O
# ---+---+---
#  O | X |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    | X |
# ---+---+---
#    |   | X
# ---+---+---
#    | O |
#
#
# Board:
#    | X |
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    | X |
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
#
# Board:
#    | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#    | O | X
#
#
# Board:
#  O | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  O | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | X
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   | X
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
#
# Board:
#    | X |
# ---+---+---
#  O |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    | X |
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
#
# Board:
#    | X | O
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X | X | O
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   | X
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
#
# Board:
#    |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   | X
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
#
# Board:
#  O |   | X
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#  O |   | X
# ---+---+---
#  X |   |
# ---+---+---
#    | O | X
#
#
# Board:
#  O |   | X
# ---+---+---
#  X |   | O
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  O |   | X
# ---+---+---
#  X |   | O
# ---+---+---
#  X | O | X
#
#
# Board:
#  O | O | X
# ---+---+---
#  X |   | O
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O | O | X
# ---+---+---
#  X | X | O
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X |   |
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#  X | O |
#
#
# Board:
#    |   |
# ---+---+---
#  O | X |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#  O | X |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X |   |
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   |
# ---+---+---
#    |   | X
# ---+---+---
#  X | O |
#
#
# Board:
#    |   |
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O |
#
#
# Board:
#    |   | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O |
#
#
# Board:
#  X |   | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | O
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  X | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | O
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   | X
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
#
# Board:
#  O |   | X
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O |   | X
# ---+---+---
#  X | X |
# ---+---+---
#    | O |
#
#
# Board:
#  O |   | X
# ---+---+---
#  X | X |
# ---+---+---
#    | O | O
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#  O |   | X
# ---+---+---
#  X | X | X
# ---+---+---
#    | O | O
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   |
# ---+---+---
#  X | X |
# ---+---+---
#    | O |
#
#
# Board:
#    |   | O
# ---+---+---
#  X | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   | O
# ---+---+---
#  X | X | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    | X |
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
#
# Board:
#    | X | O
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    | X | O
# ---+---+---
#  X |   |
# ---+---+---
#    | O | X
#
#
# Board:
#  O | X | O
# ---+---+---
#  X |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O | X | O
# ---+---+---
#  X | X |
# ---+---+---
#    | O | X
#
#
# Board:
#  O | X | O
# ---+---+---
#  X | X | O
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  O | X | O
# ---+---+---
#  X | X | O
# ---+---+---
#  X | O | X
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  X | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
#
# Board:
#  X | X |
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#  X | X | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   |
# ---+---+---
#    |   | X
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#    |   | X
# ---+---+---
#    | O |
#
#
# Board:
#  X |   |
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  X | X |
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#  O | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  X | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  O | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
#
# Board:
#    | X | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X | X | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#  X | O |
#
#
# Board:
#    | X |
# ---+---+---
#  O |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    | X |
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
#
# Board:
#    | X | O
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    | X | O
# ---+---+---
#  O | X |
# ---+---+---
#  X | O | X
#
#
# Board:
#  O | X | O
# ---+---+---
#  O | X |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#  O | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | X
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    | X |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
#
# Board:
#    | X |
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    | X |
# ---+---+---
#  O | X | X
# ---+---+---
#    | O |
#
#
# Board:
#    | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#    | O | X
#
#
# Board:
#  O | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  O | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | X
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
#
# Board:
#    |   | X
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   | X
# ---+---+---
#  O | X |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 8
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | X |
#
#
# Board:
#    |   |
# ---+---+---
#  O |   |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | X |
#
#
# Board:
#    |   | O
# ---+---+---
#  O | X |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X | O
# ---+---+---
#  O | X |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#  X | O |
#
#
# Board:
#    |   | O
# ---+---+---
#  X |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   | O
# ---+---+---
#  X |   |
# ---+---+---
#  X | O | X
#
#
# Board:
#  O |   | O
# ---+---+---
#  X |   |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#  O |   | O
# ---+---+---
#  X |   | X
# ---+---+---
#  X | O | X
#
#
# Board:
#  O | O | O
# ---+---+---
#  X |   | X
# ---+---+---
#  X | O | X
#
# Player 2 (You) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 8
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | X |
#
#
# Board:
#    |   |
# ---+---+---
#  O |   |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | X |
#
#
# Board:
#  O |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | X |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O |   | X
# ---+---+---
#  O | X |
# ---+---+---
#    | X |
#
#
# Board:
#  O |   | X
# ---+---+---
#  O | X |
# ---+---+---
#    | X | O
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  O | X | X
# ---+---+---
#  O | X |
# ---+---+---
#    | X | O
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  X |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
#
# Board:
#  X |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#  X |   |
# ---+---+---
#  O | X |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   | X
# ---+---+---
#    |   | X
# ---+---+---
#    | O |
#
#
# Board:
#    |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X |   |
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#  X | O |
#
#
# Board:
#    |   |
# ---+---+---
#  O | X |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   |
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O |
#
#
# Board:
#    |   | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | X
#
#
# Board:
#  O |   | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  O | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | X
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   |
# ---+---+---
#    |   | X
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X | X
# ---+---+---
#    | O |
#
#
# Board:
#    |   |
# ---+---+---
#  O | X | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O |
#
#
# Board:
#    |   | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O |
#
#
# Board:
#  X |   | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | O
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  X | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | O
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   | X
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
#
# Board:
#    |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   | X
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
#
# Board:
#  O |   | X
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O |   | X
# ---+---+---
#  O | X |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X |   |
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X | O | X
#
#
# Board:
#    |   |
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   |
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O | X
#
#
# Board:
#    |   | O
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O | X
#
#
# Board:
#  O | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | X
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ...
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  O | X | O
# ---+---+---
#  X | X |
# ---+---+---
#  X | O |
#
#
# Board:
#  O | X | O
# ---+---+---
#  X | X |
# ---+---+---
#  X | O | O
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#  O | X | O
# ---+---+---
#  X | X | X
# ---+---+---
#  X | O | O
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
#
# Board:
#  X |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  X | X | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
#
# Board:
#    | X |
# ---+---+---
#  O |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    | X |
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
#
# Board:
#    | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#  O | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  X | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  O | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#  X |   |
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
#
# Board:
#  X |   | O
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  X |   | O
# ---+---+---
#  X |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
#
# Board:
#  X | X |
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  X | X |
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
#
# Board:
#  X | X | O
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  X | X | O
# ---+---+---
#  O | X |
# ---+---+---
#  X | O |
#
#
# Board:
#  X | X | O
# ---+---+---
#  O | X |
# ---+---+---
#  X | O | O
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#  X | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | O
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   |
# ---+---+---
#    |   | X
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#    |   | X
# ---+---+---
#    | O |
#
#
# Board:
#    | X |
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X | X |
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#    | O | X
#
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#  O | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  X | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  O | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#  X | O |
#
#
# Board:
#    |   |
# ---+---+---
#  O | X |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#  O | X |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    | O | X
#
#
# Board:
#    |   | O
# ---+---+---
#  X |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   | O
# ---+---+---
#  X |   |
# ---+---+---
#  X | O | X
#
#
# Board:
#  O |   | O
# ---+---+---
#  X |   |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  O | X | O
# ---+---+---
#  X |   |
# ---+---+---
#  X | O | X
#
#
# Board:
#  O | X | O
# ---+---+---
#  X |   | O
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O | X | O
# ---+---+---
#  X | X | O
# ---+---+---
#  X | O | X
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X |   |
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#  X | O |
#
#
# Board:
#    |   | X
# ---+---+---
#  O |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O |
#
#
# Board:
#  O |   | X
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O |   | X
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#    | X |
# ---+---+---
#    | O |
#
#
# Board:
#    | X |
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X | X |
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
#
# Board:
#  X | X | O
# ---+---+---
#  O | X |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  X | X | O
# ---+---+---
#  O | X |
# ---+---+---
#  X | O |
#
#
# Board:
#  X | X | O
# ---+---+---
#  O | X |
# ---+---+---
#  X | O | O
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#  X | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | O
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   | X
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
#
# Board:
#  O |   | X
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  O | X | X
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
#
# Board:
#  O | X | X
# ---+---+---
#  X |   |
# ---+---+---
#    | O | O
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O | X | X
# ---+---+---
#  X | X |
# ---+---+---
#    | O | O
#
#
# Board:
#  O | X | X
# ---+---+---
#  X | X | O
# ---+---+---
#    | O | O
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  O | X | X
# ---+---+---
#  X | X | O
# ---+---+---
#  X | O | O
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X |   |
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X | O | X
#
#
# Board:
#    |   |
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
#
# Board:
#    | X | O
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O | X
#
#
# Board:
#  O | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | X
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   | X
# ---+---+---
#    |   |
# ---+---+---
#  X | O |
#
#
# Board:
#    |   | X
# ---+---+---
#  O |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#    |   | X
# ---+---+---
#  O | X |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#  X |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
#
# Board:
#  X |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  X | X | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   | X
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    | O | X
#
#
# Board:
#    |   | O
# ---+---+---
#  X |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O | X
#
#
# Board:
#  O |   | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O |   | O
# ---+---+---
#  X | X | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#  X |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 3
#
# Board:
#  X |   | X
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
#
# Board:
#  X |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#  X |   | X
# ---+---+---
#  O |   |
# ---+---+---
#    | O | X
#
#
# Board:
#  X |   | X
# ---+---+---
#  O |   | O
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  X | X | X
# ---+---+---
#  O |   | O
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   | X
#
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#  X | O | X
#
#
# Board:
#    |   |
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
#
# Board:
#  X |   | O
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#  X | X | O
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
#
# Board:
#  X | X | O
# ---+---+---
#  O |   | O
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  X | X | O
# ---+---+---
#  O | X | O
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 1
#
# Board:
#  X |   |
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
#
# Board:
#  X |   | O
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  X |   | O
# ---+---+---
#  X |   |
# ---+---+---
#  X | O |
#
# Player 1 (Smart/Random) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    |   |
# ---+---+---
#    |   | X
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#    |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   |
# ---+---+---
#  X |   | X
# ---+---+---
#    | O |
#
#
# Board:
#    |   | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    |   | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O | X
#
#
# Board:
#  O |   | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#  O |   | O
# ---+---+---
#  X |   | X
# ---+---+---
#  X | O | X
#
#
# Board:
#  O | O | O
# ---+---+---
#  X |   | X
# ---+---+---
#  X | O | X
#
# Player 2 (You) wins!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 9
#
# Board:
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#    | O | X
#
#
# Board:
#    | X |
# ---+---+---
#  O |   |
# ---+---+---
#    | O | X
#
# Player 1 (Smart/Random) chooses position 7
#
# Board:
#    | X |
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
#
# Board:
#    | X | O
# ---+---+---
#  O |   |
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O | X
#
#
# Board:
#  O | X | O
# ---+---+---
#  O |   | X
# ---+---+---
#  X | O | X
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O | X | O
# ---+---+---
#  O | X | X
# ---+---+---
#  X | O | X
#
# It's a draw!
#
# Board:
#    |   |
# ---+---+---
#    |   |
# ---+---+---
#    |   |
#
# Player 1 (Smart/Random) chooses position 4
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    |   |
#
#
# Board:
#    |   |
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 2
#
# Board:
#    | X |
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
#
# Board:
#    | X | O
# ---+---+---
#  X |   |
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 6
#
# Board:
#    | X | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O |
#
#
# Board:
#  O | X | O
# ---+---+---
#  X |   | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) chooses position 5
#
# Board:
#  O | X | O
# ---+---+---
#  X | X | X
# ---+---+---
#    | O |
#
# Player 1 (Smart/Random) wins!
# Results after 100 games:
# Wins: 2
# Losses: 82
# Draws: 16

# %%
import random
import numpy as np
from TicTacToe import TicTacToe

def generate_random_state():
    env = TicTacToe(smartMovePlayer1=0.5)  # Player 1 moves smartly, Player 2 is random
    board = [0] * 9
    num_moves = random.randint(1, 9)
    moves_made = 0
    player_turn = 1

    while moves_made < num_moves:
        valid_actions = [i for i in range(9) if board[i] == 0]
        if player_turn == 1:
            # Player 1 makes a smart or random move
            if random.random() < 0.5:  # Smart move or random move
                position = get_smart_move(board)
                if position is None:  # If no smart move, pick a random move
                    position = random.choice(valid_actions)
            else:
                position = random.choice(valid_actions)
        else:
            # Player 2 tries to block or win
            position = get_smart_move_for_p2(board)
            if position is None:
                # If no winning or blocking move, pick a random move
                position = random.choice(valid_actions)

        board[position] = player_turn
        env.board = board
        if env.check_winner(player_turn):
            break
        moves_made += 1
        player_turn = 3 - player_turn

    env.board = board
    return env, env.current_winner if env.current_winner is not None else player_turn

def get_smart_move(board):
    # Check if Player 1 can win in the next move
    for position in range(9):
        if board[position] == 0:
            board[position] = 1  # Try Player 1's move
            if check_winner(board, 1):
                board[position] = 0
                return position
            board[position] = 0
    return None

def get_smart_move_for_p2(board):
    # Check if Player 2 can win in the next move
    for position in range(9):
        if board[position] == 0:
            board[position] = 2  # Try Player 2's move
            if check_winner(board, 2):
                board[position] = 0
                return position
            board[position] = 0

    # Block Player 1 from winning
    for position in range(9):
        if board[position] == 0:
            board[position] = 1  # Pretend it's Player 1's move
            if check_winner(board, 1):
                board[position] = 0
                return position
            board[position] = 0

    return None

def check_winner(board, player):
    # Check all win conditions
    win_conditions = [
        [0, 1, 2], [3, 4, 5], [6, 7, 8],  # rows
        [0, 3, 6], [1, 4, 7], [2, 5, 8],  # columns
        [0, 4, 8], [2, 4, 6]              # diagonals
    ]
    for condition in win_conditions:
        if all(board[i] == player for i in condition):
            return True
    return False

# Updated training loop:
valid_episodes = []
for _ in range(5000):
    env, current_player = generate_random_state()
    if env.current_winner is not None or env.is_full():
        valid_episodes.append((env, env.current_winner))  # Add only valid games that have ended
    else:
        valid_episodes.append((env, current_player))  # Add incomplete games for future play

epsilon = epsilon_start
win, draw, loss = 0, 0, 0
for e, (env, current_player) in enumerate(valid_episodes):
    if current_player is None:  # Ensure current_player is never None
        continue

    state = np.reshape(env.board, [1, 9])
    done = False
    reward = 0

    while not done:
        if current_player == 2:
            action = epsilon_greedy_action(state, env, epsilon)
            if action is None:
                break
            env.make_move(action, 2)
            reward = env.get_reward()
            done = env.is_full() or env.current_winner is not None
            next_state = np.reshape(env.board, [1, 9])
            replay_buffer.append(Transition(state, action, reward, next_state, done))
            state = next_state
        else:
            if not env.is_full() and env.current_winner is None:
Loss: 0
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 9
# Episode 4977/5000, Win: 1541, Draw: 3304, Loss: 0
# Episode 4978/5000, Win: 1542, Draw: 3304, Loss: 0
# Episode 4979/5000, Win: 1543, Draw: 3304, Loss: 0
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Episode 4980/5000, Win: 1543, Draw: 3305, Loss: 0
# Player 1 (Smart/Random) chooses position 6
# Episode 4981/5000, Win: 1543, Draw: 3306, Loss: 0
# Player 1 (Smart/Random) chooses position 3
# Episode 4982/5000, Win: 1543, Draw: 3307, Loss: 0
# Episode 4983/5000, Win: 1544, Draw: 3307, Loss: 0
# Player 1 (Smart/Random) chooses position 7
# Episode 4984/5000, Win: 1544, Draw: 3308, Loss: 0
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 2
# Episode 4985/5000, Win: 1544, Draw: 3309, Loss: 0
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 5
# Episode 4986/5000, Win: 1544, Draw: 3310, Loss: 0
# Episode 4987/5000, Win: 1545, Draw: 3310, Loss: 0
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 1
# Episode 4988/5000, Win: 1545, Draw: 3311, Loss: 0
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 6
# Episode 4989/5000, Win: 1545, Draw: 3312, Loss: 0
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 3
# Episode 4990/5000, Win: 1545, Draw: 3313, Loss: 0
# Player 1 (Smart/Random) chooses position 2
# Episode 4991/5000, Win: 1545, Draw: 3314, Loss: 0
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 3
# Episode 4992/5000, Win: 1545, Draw: 3315, Loss: 0
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 5
# Episode 4993/5000, Win: 1545, Draw: 3316, Loss: 0
# Episode 4994/5000, Win: 1546, Draw: 3316, Loss: 0
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 9
# Episode 4995/5000, Win: 1546, Draw: 3317, Loss: 0
# Episode 4996/5000, Win: 1547, Draw: 3317, Loss: 0
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 7
# Episode 4997/5000, Win: 1547, Draw: 3318, Loss: 0
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 9
# Episode 4998/5000, Win: 1547, Draw: 3319, Loss: 0
# Player 1 (Smart/Random) chooses position 9
# Episode 4999/5000, Win: 1547, Draw: 3320, Loss: 0
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Episode 5000/5000, Win: 1548, Draw: 3320, Loss: 0

# %%
import numpy as np
import random
from collections import deque
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from TicTacToe import TicTacToe

class TicTacToeTrainer:
    def __init__(self):
        self.model = Sequential()
        self.model.add(Dense(64, input_dim=9, activation='relu'))
        self.model.add(Dense(64, activation='relu'))
        self.model.add(Dense(9, activation='linear'))
        self.model.compile(loss='mse', optimizer=Adam(learning_rate=0.001))
        self.epsilon = 1.0
        self.gamma = 0.95
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.memory = deque(maxlen=2000)

    def generate_random_board(self):
        board = np.zeros(9)
        for i in range(random.randint(0, 5)):
            board[random.choice([j for j in range(9) if board[j] == 0])] = random.choice([1, 2])
        return board

    def choose_action(self, state):
        # Choose action using epsilon-greedy approach
        if np.random.rand() <= self.epsilon:
            return random.choice([i for i in range(9) if state[i] == 0])  # Choose random valid move
        q_values = self.model.predict(state.reshape(1, -1))  # Predict Q-values
        return np.argmax(q_values[0])  # Select the action with the highest Q-value

    def store_experience(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def replay(self, batch_size=32):
        minibatch = random.sample(self.memory, min(len(self.memory), batch_size))
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = reward + self.gamma * np.amax(self.model.predict(next_state.reshape(1, -1))[0])
            target_f = self.model.predict(state.reshape(1, -1))
            target_f[0][action] = target
            self.model.fit(state.reshape(1, -1), target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def evaluate(self, games=20):
        wins, losses, draws = 0, 0, 0
        for _ in range(games):
            env = TicTacToe()
            state = np.array(env.board).reshape(-1)
            done = False
            while not done:
                action = self.choose_action(state)  # Choose the action as a position (0-8)
                reward = env.make_move(action, player=2)  # Make the move for Player 2 (the AI)
                # After the move, update state and check game status
                state = np.array(env.board).reshape(-1)
                if reward is not None:  # Check if the game is over (reward will indicate end of game)
                    done = True
                else:
                    done = False

            # Track game results (you may need to adjust the reward system)
            if reward == 1:  # Assuming reward = 1 for a win
                wins += 1
            elif reward == -1:  # Assuming reward = -1 for a loss
                losses += 1
            else:  # Draw
                draws += 1
        print(f"Stats: Wins: {wins}, Losses: {losses}, Draws: {draws}")

def train_tic_tac_toe():
    trainer = TicTacToeTrainer()
    episodes = 1000
    evaluation_interval = 100

    for episode in range(episodes):
        env = TicTacToe()
        state = trainer.generate_random_board()  # Random board initialization
        env.board = state.reshape(9,1)  # Set the board to the random initial state (3x3)
        state = np.array(env.board).reshape(-1)  # Flatten the board for the neural network input
        done = False
        
        while not done:
            action = trainer.choose_action(state)  # Choose action as a position (0-8)
            
            # Make the move for Player 2 (AI)
            reward = env.make_move(action, player=2)  # Make the move for Player 2
            
            if reward is not None:  # If the game is finished, reward will not be None
                done = True
            else:
                state = np.array(env.board).reshape(-1)  # Update state for the next move
                
            trainer.store_experience(state, action, reward, state, done)  # Store experience
            state = np.array(env.board).reshape(-1)  # Update state after the move

        trainer.replay(batch_size=32)  # Experience replay for model training

        if episode % evaluation_interval == 0:
            print(f"Episode {episode} Evaluation:")
            trainer.evaluate(games=20)

    trainer.model.save('h67.h5')  # Save the trained model after all episodes

train_tic_tac_toe()  # Start the training
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Episode 0 Evaluation:
# Stats: Wins: 20, Losses: 0, Draws: 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 109
#     105             trainer.evaluate(games=20)
#     107     trainer.model.save('h67.h5')  # Save the trained model after all episodes
# --> 109 train_tic_tac_toe()
#
# Cell In[31], line 101, in train_tic_tac_toe()
#      98     trainer.store_experience(state, action, reward, state, done)  # Store experience
#      99     state = np.array(env.board).reshape(-1)  # Update state after the move
# --> 101 trainer.replay(batch_size=32)  # Experience replay for model training
#     103 if episode % evaluation_interval == 0:
#     104     print(f"Episode {episode} Evaluation:")
#
# Cell In[31], line 44, in TicTacToeTrainer.replay(self, batch_size)
#      42 if not done:
#      43     target = reward + self.gamma * np.amax(self.model.predict(next_state.reshape(1, -1))[0])
# ---> 44 target_f = self.model.predict(state.reshape(1, -1))
#      45 target_f[0][action] = target
#      46 self.model.fit(state.reshape(1, -1), target_f, epochs=1, verbose=0)
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:448, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     443 @traceback_utils.filter_traceback
#     444 def predict(
#     445     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     446 ):
#     447     # Create an iterator that yields batches of input data.
# --> 448     epoch_iterator = TFEpochIterator(
#     449         x=x,
#     450         batch_size=batch_size,
#     451         steps_per_epoch=steps,
#     452         shuffle=False,
#     453         distribute_strategy=self.distribute_strategy,
#     454         steps_per_execution=self.steps_per_execution,
#     455     )
#     457     # Container that configures and calls callbacks.
#     458     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:666, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     664 super().__init__(*args, **kwargs)
#     665 self._distribute_strategy = distribute_strategy
# --> 666 dataset = self._get_iterator()
#     667 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     668     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     669         dataset
#     670     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:675, in TFEpochIterator._get_iterator(self)
#     674 def _get_iterator(self):
# --> 675     return self.data_adapter.get_tf_dataset()
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:232, in ArrayDataAdapter.get_tf_dataset(self)
#     229     dataset = dataset.with_options(options)
#     230     return dataset
# --> 232 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     233 if shuffle == "batch":
#     234     indices_dataset = indices_dataset.map(tf.random.shuffle)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/data/ops/dataset_ops.py:2389, in DatasetV2.flat_map(self, map_func, name)
#    2385 # Loaded lazily due to a circular dependency (dataset_ops -> flat_map_op ->
#    2386 # dataset_ops).
#    2387 # pylint: disable=g-import-not-at-top,protected-access
#    2388 from tensorflow.python.data.ops import flat_map_op
# -> 2389 return flat_map_op._flat_map(self, map_func, name=name)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/data/ops/flat_map_op.py:24, in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/data/ops/flat_map_op.py:33, in _FlatMapDataset.__init__(self, input_dataset, map_func, name)
#      30 def __init__(self, input_dataset, map_func, name=None):
#      32   self._input_dataset = input_dataset
# ---> 33   self._map_func = structured_function.StructuredFunctionWrapper(
#      34       map_func, self._transformation_name(), dataset=input_dataset)
#      35   if not isinstance(self._map_func.output_structure, dataset_ops.DatasetSpec):
#      36     raise TypeError(
#      37         "The `map_func` argument must return a `Dataset` object. Got "
#      38         f"{dataset_ops.get_type(self._map_func.output_structure)!r}.")
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/data/ops/structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1251, in Function.get_concrete_function(self, *args, **kwargs)
#    1249 def get_concrete_function(self, *args, **kwargs):
#    1250   # Implements PolymorphicFunction.get_concrete_function.
# -> 1251   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1252   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1253   return concrete
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1221, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1219   if self._variable_creation_config is None:
#    1220     initializers = []
# -> 1221     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1222     self._initialize_uninitialized_variables(initializers)
#    1224 if self._created_variables:
#    1225   # In this case we have created variables on the first call, so we run the
#    1226   # version which is guaranteed to never create variables.
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/data/ops/structured_function.py:231, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     230 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 231   ret = wrapper_helper(*args)
#     232   ret = structure.to_tensor_list(self._output_structure, ret)
#     233   return [ops.convert_to_tensor(t) for t in ret]
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/data/ops/structured_function.py:161, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     159 if not _should_unpack(nested_args):
#     160   nested_args = (nested_args,)
# --> 161 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     162 ret = variable_utils.convert_variables_to_tensors(ret)
#     163 if _should_pack(ret):
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:160, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_batch_indices(indices)
#     143 """Convert a Tensor of indices into a dataset of batched indices.
#     144
#     145 This step can be accomplished in several ways. The most natural is
#    (...)
#     157     A Dataset of batched indices.
#     158 """
#     159 num_in_full_batch = num_full_batches * batch_size
# --> 160 first_k_indices = tf.slice(indices, [0], [num_in_full_batch])
#     161 first_k_indices = tf.reshape(
#     162     first_k_indices, [num_full_batches, batch_size]
#     163 )
#     165 flat_dataset = tf.data.Dataset.from_tensor_slices(first_k_indices)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/ops/array_ops.py:991, in slice(input_, begin, size, name)
#     939 @tf_export("slice")
#     940 @dispatch.add_dispatch_support
#     941 def slice(input_, begin, size, name=None):
#     942   # pylint: disable=redefined-builtin
#     943   """Extracts a slice from a tensor.
#     944
#     945   See also `tf.strided_slice`.
#    (...)
#     989     A `Tensor` the same type as `input_`.
#     990   """
# --> 991   return gen_array_ops._slice(input_, begin, size, name=name)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/ops/gen_array_ops.py:9901, in _slice(input, begin, size, name)
#    9899     pass  # Add nodes to the TensorFlow graph.
#    9900 # Add nodes to the TensorFlow graph.
# -> 9901 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    9902       "Slice", input=input, begin=begin, size=size, name=name)
#    9903 _result = _outputs[:]
#    9904 if _execute.must_record_gradient():
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/op_def_library.py:778, in _apply_op_helper(op_type_name, name, **keywords)
#     776 with g.as_default(), ops.name_scope(name) as scope:
#     777   if fallback:
# --> 778     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     779                            keywords, default_type_attr_map, attrs, inputs,
#     780                            input_types)
#     781     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     782                            default_type_attr_map, attrs)
#     783     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/op_def_library.py:551, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     545       values = ops.convert_to_tensor(
#     546           values,
#     547           name=input_arg.name,
#     548           as_ref=input_arg.is_ref,
#     549           preferred_dtype=default_dtype)
#     550   else:
# --> 551     values = ops.convert_to_tensor(
#     552         values,
#     553         name=input_arg.name,
#     554         dtype=dtype,
#     555         as_ref=input_arg.is_ref,
#     556         preferred_dtype=default_dtype)
#     557 except TypeError as err:
#     558   if dtype is None:
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:732, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     730 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     731 preferred_dtype = preferred_dtype or dtype_hint
# --> 732 return tensor_conversion_registry.convert(
#     733     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     734 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/constant_tensor_conversion.py:29, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#      26 from tensorflow.python.framework import constant_op  # pylint: disable=g-import-not-at-top
#      28 _ = as_ref
# ---> 29 return constant_op.constant(v, dtype=dtype, name=name)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/ops/weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/constant_op.py:276, in constant(value, dtype, shape, name)
#     177 @tf_export("constant", v1=[])
#     178 def constant(
#     179     value, dtype=None, shape=None, name="Const"
#     180 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     181   """Creates a constant tensor from a tensor-like object.
#     182
#     183   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     274     ValueError: if called on a symbolic tensor.
#     275   """
# --> 276   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     277                         allow_broadcast=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/constant_op.py:291, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     288       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     289   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 291 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     292     value, dtype, shape, name, verify_shape, allow_broadcast
#     293 )
#     294 return const_tensor
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:289, in _create_graph_constant(value, dtype, shape, name, verify_shape, allow_broadcast)
#     287 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     288 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 289 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     290     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     292 if op_callbacks.should_invoke_op_callbacks():
#     293   # TODO(b/147670703): Once the special-op creation code paths
#     294   # are unified. Remove this `if` block.
#     295   callback_outputs = op_callbacks.invoke_op_callbacks(
#     296       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/func_graph.py:661, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     657     return inputs[0].op
#     658 # Calling AddValue on the control flow contexts to force creation of the
#     659 # backward accumulators in the original graph before we create placeholders
#     660 # to capture the inputs.
# --> 661 ctxt = ops.get_default_graph()._control_flow_context  # pylint: disable=protected-access
#     662 # Use a different list to avoid modifying the original inputs list.
#     663 captured_inputs = []
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:5117, in get_default_graph()
#    5111     raise AssertionError("Do not use tf.reset_default_graph() to clear "
#    5112                          "nested graphs. If you need a cleared graph, "
#    5113                          "exit the nesting and create a new graph.")
#    5114   _default_graph_stack.reset()
# -> 5117 @tf_export(v1=["get_default_graph"])
#    5118 def get_default_graph() -> Graph:
#    5119   """Returns the default graph for the current thread.
#    5120
#    5121   The returned graph will be the innermost graph on which a
#    (...)
#    5140     The default `Graph` being used in the current thread.
#    5141   """
#    5142   return _default_graph_stack.get_default()
#
# KeyboardInterrupt:

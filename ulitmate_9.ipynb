# %%
import numpy as np
import random
from collections import deque
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from TicTacToe import TicTacToe

class SQNAgent:
    def __init__(self, state_size=9, action_size=9, gamma=0.95):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = gamma  
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.9995
        self.batch_size = 32
        self.replay_buffer = deque(maxlen=10000)
        self.model = self._build_model()

    def _build_model(self):
        model = Sequential([
            Dense(64, input_dim=self.state_size, activation='relu'),
            Dense(64, activation='relu'),
            Dense(self.action_size, activation='linear')
        ])
        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))
        return model

    def process_state(self, state):
        processed = np.array(state).astype(float)
        processed[processed == 1] = -1
        processed[processed == 2] = 1   
        return processed

    def select_action(self, state, valid_actions):
        if not valid_actions:
            return None

        if random.random() < self.epsilon:
            return random.choice(valid_actions)
        
        processed_state = self.process_state(state)
        q_values = self.model.predict(processed_state.reshape(1, -1), verbose=0)[0]
        valid_q_values = [(q_values[action], action) for action in valid_actions]
        return max(valid_q_values, key=lambda x: x[0])[1]

    def store_experience(self, state, action, reward, next_state, done):
        self.replay_buffer.append((state, action, reward, next_state, done))

    def train(self):
        if len(self.replay_buffer) < self.batch_size:
            return

        mini_batch = random.sample(self.replay_buffer, self.batch_size)
        states = np.array([self.process_state(exp[0]) for exp in mini_batch])
        next_states = np.array([self.process_state(exp[3]) for exp in mini_batch])
        current_q_values = self.model.predict(states, verbose=0)
        next_q_values = self.model.predict(next_states, verbose=0)

        x = []
        y = []

        for i, (state, action, reward, next_state, done) in enumerate(mini_batch):
            if done:
                target = reward
            else:
                next_valid_actions = [j for j, val in enumerate(next_state) if val == 0]
                if next_valid_actions:
                    max_next_q = max(next_q_values[i][action] for action in next_valid_actions)
                    target = reward + self.gamma * max_next_q
                else:
                    target = reward
            
            current_q = current_q_values[i].copy()
            current_q[action] = target
            x.append(self.process_state(state))
            y.append(current_q)

        self.model.fit(np.array(x), np.array(y), batch_size=32, epochs=1, verbose=0)

def train_agent(episodes=10000):
    agent = SQNAgent()
    history = {'wins': 0, 'losses': 0, 'draws': 0}
    initial_epsilon = 1.0
    min_epsilon = 0.01
    decay_episodes = 1000
    target_ratio = 1.0
    prioritize_draw = False
    
    for episode in range(episodes):
        if episode % 2000 == 0 and episode > 0:
            agent.epsilon = 1.0
            print("Resetting epsilon to 1.0")
        else:
            epsilon_decay = (initial_epsilon - min_epsilon) / decay_episodes
            agent.epsilon = max(min_epsilon, initial_epsilon - (episode % 2000) * epsilon_decay)
        
        smartness = min(1, episode / (episodes * 0.6))
        game = TicTacToe(smartMovePlayer1=smartness)
        state = np.array(game.board)
        
        game.player1_move()
        state = np.array(game.board)
        
        while True:
            valid_actions = game.empty_positions()
            if not valid_actions:
                history['draws'] += 1
                break
            
            action = agent.select_action(state, valid_actions)
            game.make_move(action, player=2)
            
            reward = 0
            if game.current_winner == 2:
                reward = 1.0
                history['wins'] += 1
                agent.store_experience(state, action, reward, game.board, True)
                break
            
            game.player1_move()
            if game.current_winner == 1:
                reward = -1.0
                history['losses'] += 1
                agent.store_experience(state, action, reward, game.board, True)
                break
            elif game.is_full():
                reward = 0.2 if prioritize_draw else 0.0
                history['draws'] += 1
                agent.store_experience(state, action, reward, game.board, True)
                break
            
            agent.store_experience(state, action, reward, game.board, False)
            state = np.array(game.board)
        
        agent.train()
        
        if episode % 1000 == 0:
            win_ratio = history['wins'] / (history['losses'] + 1e-5)
            if win_ratio < target_ratio and episode >= 100:
                prioritize_draw = True
                agent.epsilon = min(agent.epsilon + 0.1, 1.0)
            else:
                prioritize_draw = False
            print(f"Episode: {episode}, Win/Loss Ratio: {win_ratio:.2f}, Epsilon: {agent.epsilon:.3f}, smartmove: {smartness}")
            print(f"Wins: {history['wins']}, Losses: {history['losses']}, Draws: {history['draws']}")
        
        if episode % 1000 == 0:
            agent.model.save(f'model13_episode_{episode}.h5')
            print(f"Model saved at episode {episode}")

    agent.model.save('model13_final.h5')



agent = train_agent()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.00, Adjusted Epsilon: 1.000
# Episode: 0, Win/Loss Ratio: 0.00, Epsilon: 1.000, smartmove: 0.0
# Wins: 0, Losses: 1, Draws: 0
# Model saved at episode 0
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.00, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.00, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.00, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.00, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.00, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.00, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.00, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.00, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.00, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.00, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.00, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.00, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.08, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.08, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.07, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.14, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.13, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.20, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.20, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.19, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.18, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.17, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.16, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.15, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.20, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.25, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.25, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.30, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.29, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.27, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.26, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.25, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.29, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.33, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.32, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.36, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.35, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.33, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.32, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.31, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.34, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.33, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.32, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.31, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.34, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.33, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.36, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.35, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.38, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 8
# Prioritizing draws. Win-to-Loss Ratio: 0.37, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.36, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.35, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.34, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.33, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.32, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.35, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.34, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.37, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.36, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.35, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.35, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.37, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.40, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.42, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.42, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.42, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.41, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.41, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.43, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 8
# Prioritizing draws. Win-to-Loss Ratio: 0.43, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.42, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.44, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.43, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.43, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.45, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.46, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 8
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 8
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.46, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.51, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.53, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.52, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.51, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.52, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 8
# Prioritizing draws. Win-to-Loss Ratio: 0.51, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.53, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.52, Adjusted Epsilon: 1.000
# Episode: 100, Win/Loss Ratio: 0.52, Epsilon: 1.000, smartmove: 0.016666666666666666
# Wins: 30, Losses: 58, Draws: 13
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.51, Adjusted Epsilon: 1.000
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 0.999
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.52, Adjusted Epsilon: 0.998
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.51, Adjusted Epsilon: 0.997
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 0.996
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 0.995
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.52, Adjusted Epsilon: 0.994
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.51, Adjusted Epsilon: 0.993
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 0.992
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.52, Adjusted Epsilon: 0.991
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.51, Adjusted Epsilon: 0.990
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 0.989
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.988
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.987
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 0.986
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.985
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.51, Adjusted Epsilon: 0.984
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 0.983
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 0.982
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 8
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.981
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.980
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.979
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 8
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.978
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.977
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.976
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.975
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.974
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.973
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.972
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.971
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.970
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.969
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.968
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.967
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.966
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.965
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.964
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.963
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.962
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.46, Adjusted Epsilon: 0.961
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.960
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.959
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.958
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.957
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.956
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.955
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.954
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.953
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.952
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.952
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 8
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.951
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.950
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.949
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.948
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.947
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.946
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 8
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.945
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.944
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.943
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.46, Adjusted Epsilon: 0.942
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.46, Adjusted Epsilon: 0.941
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.940
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.939
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.938
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 8
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 0.937
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 8
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.936
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.935
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 8
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.934
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 8
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 0.933
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 0.932
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 2
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 0.931
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 3
# Prioritizing draws. Win-to-Loss Ratio: 0.50, Adjusted Epsilon: 0.930
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 9
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.929
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 4
# Prioritizing draws. Win-to-Loss Ratio: 0.49, Adjusted Epsilon: 0.928
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.927
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.926
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.925
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.924
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.923
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.922
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.921
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 7
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.920
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.919
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 1
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 6
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.918
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.917
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 3
# Player 1 (Smart/Random) chooses position 5
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.916
# Player 1 (Smart/Random) chooses position 2
# Player 1 (Smart/Random) chooses position 7
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.915
# Player 1 (Smart/Random) chooses position 5
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.47, Adjusted Epsilon: 0.914
# Player 1 (Smart/Random) chooses position 6
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# Prioritizing draws. Win-to-Loss Ratio: 0.48, Adjusted Epsilon: 0.913
# Player 1 (Smart/Random) chooses position 4
# Player 1 (Smart/Random) chooses position 9
# Player 1 (Smart/Random) chooses position 1
# ...
# Player 1 (Smart/Random) chooses position 8
# Player 1 (Smart/Random) chooses position 9
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:3080, in Graph.op_def_for_type(self, type)
#    3079 try:
# -> 3080   return self._op_def_cache[type]
#    3081 except KeyError:
#
# KeyError: 'Placeholder'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 158
#     153             print(f"Model saved at episode {episode}")
#     155     agent.model.save('model13_final.h5')
# --> 158 agent = train_agent()
#
# Cell In[1], line 112, in train_agent(episodes)
#     109     history['draws'] += 1
#     110     break
# --> 112 action = agent.select_action(state, valid_actions)
#     113 game.make_move(action, player=2)
#     115 reward = 0
#
# Cell In[1], line 45, in SQNAgent.select_action(self, state, valid_actions)
#      42     return random.choice(valid_actions)
#      44 processed_state = self.process_state(state)
# ---> 45 q_values = self.model.predict(processed_state.reshape(1, -1), verbose=0)[0]
#      46 valid_q_values = [(q_values[action], action) for action in valid_actions]
#      47 return max(valid_q_values, key=lambda x: x[0])[1]
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:448, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     443 @traceback_utils.filter_traceback
#     444 def predict(
#     445     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     446 ):
#     447     # Create an iterator that yields batches of input data.
# --> 448     epoch_iterator = TFEpochIterator(
#     449         x=x,
#     450         batch_size=batch_size,
#     451         steps_per_epoch=steps,
#     452         shuffle=False,
#     453         distribute_strategy=self.distribute_strategy,
#     454         steps_per_execution=self.steps_per_execution,
#     455     )
#     457     # Container that configures and calls callbacks.
#     458     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:666, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     664 super().__init__(*args, **kwargs)
#     665 self._distribute_strategy = distribute_strategy
# --> 666 dataset = self._get_iterator()
#     667 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     668     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     669         dataset
#     670     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:675, in TFEpochIterator._get_iterator(self)
#     674 def _get_iterator(self):
# --> 675     return self.data_adapter.get_tf_dataset()
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:236, in ArrayDataAdapter.get_tf_dataset(self)
#     233 if shuffle == "batch":
#     234     indices_dataset = indices_dataset.map(tf.random.shuffle)
# --> 236 dataset = slice_inputs(indices_dataset, self._inputs)
#     238 options = tf.data.Options()
#     239 options.experimental_distribute.auto_shard_policy = (
#     240     tf.data.experimental.AutoShardPolicy.DATA
#     241 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:215, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_inputs(indices_dataset, inputs)
#     211         return x
#     213     return tree.traverse(grab_one, data)
# --> 215 dataset = dataset.map(
#     216     grab_batch, num_parallel_calls=tf.data.AUTOTUNE
#     217 )
#     219 # Default optimizations are disabled to avoid the overhead of
#     220 # (unnecessary) input pipeline graph serialization & deserialization
#     221 options = tf.data.Options()
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/data/ops/dataset_ops.py:2341, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, synchronous, use_unbounded_threadpool, name)
#    2336 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2337 # dataset_ops).
#    2338 # pylint: disable=g-import-not-at-top,protected-access
#    2339 from tensorflow.python.data.ops import map_op
# -> 2341 return map_op._map_v2(
#    2342     self,
#    2343     map_func,
#    2344     num_parallel_calls=num_parallel_calls,
#    2345     deterministic=deterministic,
#    2346     synchronous=synchronous,
#    2347     use_unbounded_threadpool=use_unbounded_threadpool,
#    2348     name=name,
#    2349 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/data/ops/map_op.py:57, in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, synchronous, use_unbounded_threadpool, name)
#      51 if synchronous:
#      52   raise ValueError(
#      53       "`synchronous` is not supported with `num_parallel_calls`, but"
#      54       " `num_parallel_calls` was set to ",
#      55       num_parallel_calls,
#      56   )
# ---> 57 return _ParallelMapDataset(
#      58     input_dataset,
#      59     map_func,
#      60     num_parallel_calls=num_parallel_calls,
#      61     deterministic=deterministic,
#      62     preserve_cardinality=True,
#      63     use_unbounded_threadpool=use_unbounded_threadpool,
#      64     name=name)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/data/ops/map_op.py:202, in _ParallelMapDataset.__init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, use_unbounded_threadpool, name)
#     200 self._input_dataset = input_dataset
#     201 self._use_inter_op_parallelism = use_inter_op_parallelism
# --> 202 self._map_func = structured_function.StructuredFunctionWrapper(
#     203     map_func,
#     204     self._transformation_name(),
#     205     dataset=input_dataset,
#     206     use_legacy_function=use_legacy_function)
#     207 if deterministic is None:
#     208   self._deterministic = "default"
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/data/ops/structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1251, in Function.get_concrete_function(self, *args, **kwargs)
#    1249 def get_concrete_function(self, *args, **kwargs):
#    1250   # Implements PolymorphicFunction.get_concrete_function.
# -> 1251   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1252   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1253   return concrete
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1221, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1219   if self._variable_creation_config is None:
#    1220     initializers = []
# -> 1221     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1222     self._initialize_uninitialized_variables(initializers)
#    1224 if self._created_variables:
#    1225   # In this case we have created variables on the first call, so we run the
#    1226   # version which is guaranteed to never create variables.
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:303, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     299 placeholder_context = trace_type.InternalPlaceholderContext(
#     300     func_graph, type_context.get_placeholder_mapping()
#     301 )
#     302 with func_graph.as_default():
# --> 303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
#     310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#    (...)
#     319     create_placeholders=False,
#     320 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/core/function/polymorphism/function_type.py:356, in FunctionType.placeholder_arguments(self, placeholder_context)
#     353     raise ValueError("Can not generate placeholder value for "
#     354                      "partially defined function type.")
#     355   placeholder_context.update_naming_scope(parameter.name)
# --> 356   arguments[parameter.name] = parameter.type_constraint.placeholder_value(
#     357       placeholder_context)
#     359 return inspect.BoundArguments(self, arguments)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/tensor.py:1021, in TensorSpec.placeholder_value(self, placeholder_context)
#    1019     placeholder = self._graph_placeholder(context_graph, name=name)
#    1020 else:
# -> 1021   placeholder = self._graph_placeholder(context_graph, name=name)
#    1023 if name is not None:
#    1024   # Record the requested/user-specified name in case it's different than
#    1025   # the uniquified name, for validation when exporting signatures.
#    1026   placeholder.op._set_attr(  # pylint: disable=protected-access
#    1027       "_user_specified_name",
#    1028       attr_value_pb2.AttrValue(s=compat.as_bytes(name)))
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/tensor.py:1059, in TensorSpec._graph_placeholder(self, graph, name)
#    1057 attrs = {"dtype": dtype_value, "shape": shape}
#    1058 try:
# -> 1059   op = graph._create_op_internal(  # pylint: disable=protected-access
#    1060       "Placeholder", [], [dtype], input_types=[],
#    1061       attrs=attrs, name=name)
#    1062 except ValueError as e:
#    1063   # TODO(b/262413656) Sometimes parameter names are not valid op names, in
#    1064   # which case an unnamed placeholder is created instead. Update this logic
#    1065   # to sanitize the name instead of falling back on unnamed placeholders.
#    1066   logging.warning(e)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:2701, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2698 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2699 # Session.run call cannot occur between creating and mutating the op.
#    2700 with self._mutation_lock():
# -> 2701   ret = Operation.from_node_def(
#    2702       node_def,
#    2703       self,
#    2704       inputs=inputs,
#    2705       output_types=dtypes,
#    2706       control_inputs=control_inputs,
#    2707       input_types=input_types,
#    2708       original_op=self._default_original_op,
#    2709       op_def=op_def,
#    2710   )
#    2711   self._create_op_helper(ret, compute_device=compute_device)
#    2712 return ret
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:1196, in Operation.from_node_def(***failed resolving arguments***)
#    1193     control_input_ops.append(control_op)
#    1195 # Initialize c_op from node_def and other inputs
# -> 1196 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1197 self = Operation(c_op, SymbolicTensor)
#    1198 self._init(g)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:1020, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1003 """Creates a TF_Operation.
#    1004
#    1005 Args:
#    (...)
#    1017   A wrapped TF_Operation*.
#    1018 """
#    1019 if op_def is None:
# -> 1020   op_def = graph.op_def_for_type(node_def.op)  # pylint: disable=protected-access
#    1021 # TODO(skyewm): op_def_library.apply_op() flattens the incoming inputs.
#    1022 # Refactor so we don't have to do this here.
#    1023 inputs = _reconstruct_sequence_inputs(op_def, inputs, node_def.attr)
#
# File /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:3082, in Graph.op_def_for_type(self, type)
#    3080   return self._op_def_cache[type]
#    3081 except KeyError:
# -> 3082   self._op_def_cache[type] = op_def_pb2.OpDef.FromString(
#    3083       self._op_def_for_type(type)
#    3084   )
#    3085   return self._op_def_cache[type]
#
# KeyboardInterrupt:
